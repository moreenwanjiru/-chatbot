# %%
import os
from openai import OpenAI
from IPython.display import display
import ipywidgets as widgets
import time
from comet_ml import init
from dotenv import load_dotenv


# print("Success")

# %%
# Input API keys
# Load environment variables from .env.local file
load_dotenv(".env.local")

# Get the API key from the environment variable
api_key = os.environ.get("MY_OPENAI_KEY")

# Use the API key
# print(api_key)


MY_OPENAI_KEY = os.getenv("MY_OPENAI_KEY")
MY_COMET_KEY = os.getenv("MY_COMET_KEY")


init(
    # project="ecom-supermarket-bot",
      project_name="ecom-supermarket-bot",
      workspace="lyznne",
    api_key=MY_COMET_KEY,
)

print("Success")
# Out:
# COMET INFO: Valid Comet API Key saved in /home/enos/.comet.config (set COMET_CONFIG to change where it is saved).
# Success

# %%
# the product list


product_list = """
# Supermarket Product List

## Fresh Produce:
- Apples - Price: Ksh 300/lb
- Bananas - Price: Ksh 60/lb
- Oranges - Price: Ksh 350/bag
- Lettuce - Price: Ksh 180/head
- Tomatoes - Price: Ksh 250/lb
- Potatoes - Price: Ksh 400/5lb bag
- Carrots - Price: Ksh 200/2lb bag

## Dairy:
- Milk (1 gallon) - Price: Ksh 380
- Eggs (dozen) - Price: Ksh 300
- Cheddar Cheese (8 oz) - Price: Ksh 250
- Yogurt (6 oz) - Price: Ksh 100
- Butter (1 lb) - Price: Ksh 430

## Bakery:
- Sliced Bread (loaf) - Price: Ksh 250
- Bagels (6 pack) - Price: Ksh 400
- Muffins (4 pack) - Price: Ksh 350
- Donuts (6 pack) - Price: Ksh 500
- Cakes (9 inch) - Price: Ksh 1300

## Meat:
- Ground Beef (1 lb) - Price: Ksh 500
- Chicken Breasts (1 lb) - Price: Ksh 400
- Salmon Fillets (1 lb) - Price: Ksh 900
- Pork Chops (1 lb) - Price: Ksh 550
- Beef Steaks (1 lb) - Price: Ksh 1000

## Frozen Foods:
- Frozen Pizza (12 inch) - Price: Ksh 600
- Frozen Vegetables (16 oz) - Price: Ksh 250
- Ice Cream (1.5 qt) - Price: Ksh 500
- Frozen Waffles (12 count) - Price: Ksh 350
- Frozen Burritos (8 pack) - Price: Ksh 700

## Pantry Items:
- Pasta (16 oz) - Price: Ksh 200
- Rice (2 lb bag) - Price: Ksh 350
- Canned Beans (15 oz) - Price: Ksh 100
- Tomato Sauce (24 oz) - Price: Ksh 180
- Cereal (12 oz box) - Price: Ksh 400
- Peanut Butter (16 oz) - Price: Ksh 250

## Beverages:
- Soda (2 liter) - Price: Ksh 200
- Bottled Water (24 pack) - Price: Ksh 500
- Orange Juice (1 gallon) - Price: Ksh 380
- Coffee (12 oz bag) - Price: Ksh 700
- Tea Bags (100 count) - Price: Ksh 350

## Fresh Produce:
- Apples - Price: Ksh 150 per pound
- Bananas - Price: Ksh 60 per pound
- Carrots - Price: Ksh 80 per pound
- Lettuce - Price: Ksh 120 per head

## Dairy and Eggs:
- Milk (1 Gallon) - Price: Ksh 350
- Eggs (Dozen) - Price: Ksh 200
- Cheese (Cheddar, 8 oz) - Price: Ksh 250
- Yogurt (Assorted Flavors, 16 oz) - Price: Ksh 120 each

## Bakery:
- Bread (White or Wheat) - Price: Ksh 200 per loaf
- Bagels (Assorted Varieties, 6-pack) - Price: Ksh 350
- Croissants (Plain or Chocolate) - Price: Ksh 150 each
- Muffins (Blueberry, Chocolate Chip) - Price: Ksh 75 each

## Meat and Poultry:
- Chicken Breast (Boneless, Skinless, 1 lb) - Price: Ksh 350
- Ground Beef (80/20, 1 lb) - Price: Ksh 400
- Pork Chops (Bone-In, 1 lb) - Price: Ksh 375
- Salmon Fillet (Fresh, 1 lb) - Price: Ksh 750

## Beverages:
- Bottled Water (24-pack) - Price: Ksh 450
- Soda Cans (Assorted Flavors, 12-pack) - Price: Ksh 500
- Coffee (Ground, Assorted Blends, 12 oz) - Price: Ksh 600
- Tea (Assorted Varieties, 20 bags) - Price: Ksh 250

## Frozen Foods:
- Frozen Pizza (Assorted Flavors) - Price: Ksh 500 each
- Ice Cream (Assorted Flavors, 1 pint) - Price: Ksh 350
- Frozen Vegetables (Assorted Varieties, 16 oz) - Price: Ksh 175 each
- Chicken Nuggets (Family Pack, 32 oz) - Price: Ksh 650

## Snacks and Sweets:
- Potato Chips (Assorted Flavors, Family Size) - Price: Ksh 300
- Chocolate Bars (Assorted Varieties) - Price: Ksh 125 each
- Pretzels (Regular or Honey Mustard, 8 oz) - Price: Ksh 150
- Candy (Assorted Varieties, Bag) - Price: Ksh 250

## Household Essentials:
- Toilet Paper (12 Rolls) - Price: Ksh 600
- Paper Towels (6 Rolls) - Price: Ksh 450
- Laundry Detergent (Assorted Brands, 50 oz) - Price: Ksh 800
- Dish Soap (Assorted Scents, 24 oz) - Price: Ksh 350

"""
context = [
    {
        "role": "system",
        "content": f"""
            Welcome to SuperShopBot, your friendly AI assistant for our online supermarket! 
            Our mission is to make your shopping experience convenient and enjoyable. 
            We offer a wide range of products across various categories including Fresh Produce,
            Dairy and Eggs, Bakery, Meat and Poultry, Beverages, Frozen Foods, Snacks and Sweets, and Household Essentials.
            
            Feel free to explore our selection and let us know if you need any assistance or 
            have any questions. Here's a glimpse of what we have available: ```{product_list}``` 
            """,
    }
]

# %%
# Create a Chatbot
def get_completion_from_messages(messages, model="gpt-3.5-turbo"):
    client = OpenAI(
        api_key=MY_OPENAI_KEY,
    )

    chat_completion = client.chat.completions.create(
        messages=messages,
        model=model,
    )
    return chat_completion.choices[0].message.content

# %%
# Interacting with Customers

def collect_messages(_):
    user_input = inp.value
    inp.value = ''
    context.append({'role':'user', 'content':f"{user_input}"})

    # Record the start time
    start_time = time.time()  

    response = get_completion_from_messages(context) 

    # Record the end time
    end_time = time.time()  

    # Calculate the duration
    duration = end_time - start_time  

    # Log to comet_llm
    comet_llm.log_prompt(
        prompt=user_input,
        output=response,
        duration=duration,
        metadata={
        "role": context[-1]['role'],
        "content": context[-1]['content'],
        "context": context,
        "product_list": product_list
        },
    )

    context.append({'role': 'assistant', 'content': f"{response}"})

    user_pane = widgets.Output()
    with user_pane:
        display(widgets.HTML(f"<b>User:</b> {user_input}"))

    assistant_pane = widgets.Output()
    with assistant_pane:
        display(widgets.HTML(f"<b>Assistant:</b> {response}"))

    display(widgets.VBox([user_pane, assistant_pane]))

inp = widgets.Text(value="Hi", placeholder='Enter text here…')
button_conversation = widgets.Button(description="Chat!")
button_conversation.on_click(collect_messages)

dashboard = widgets.VBox([inp, button_conversation])

display(dashboard)
# Out:
# ...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 11, in collect_messages(_)
#       8 # Record the start time
#       9 start_time = time.time()
# ---> 11 response = get_completion_from_messages(context)
#      13 # Record the end time
#      14 end_time = time.time()
#
# Cell In[6], line 7, in get_completion_from_messages(messages, model)
#       2 def get_completion_from_messages(messages, model="gpt-3.5-turbo"):
#       3     client = OpenAI(
#       4         api_key=MY_OPENAI_KEY,
#       5     )
# ----> 7     chat_completion = client.chat.completions.create(
#       8         messages=messages,
#       9         model=model,
#      10     )
#      11     return chat_completion.choices[0].message.content
#
# ...

# %%
messages =  context.copy()
messages.append(
{'role':'system'
 , 'content':'create a table summary of the previous order.'}   
)

response = get_completion_from_messages(messages)
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 11, in collect_messages(_)
#       8 # Record the start time
#       9 start_time = time.time()
# ---> 11 response = get_completion_from_messages(context)
#      13 # Record the end time
#      14 end_time = time.time()
#
# Cell In[6], line 7, in get_completion_from_messages(messages, model)
#       2 def get_completion_from_messages(messages, model="gpt-3.5-turbo"):
#       3     client = OpenAI(
#       4         api_key=MY_OPENAI_KEY,
#       5     )
# ----> 7     chat_completion = client.chat.completions.create(
#       8         messages=messages,
#       9         model=model,
#      10     )
#      11     return chat_completion.choices[0].message.content
#
# ...
